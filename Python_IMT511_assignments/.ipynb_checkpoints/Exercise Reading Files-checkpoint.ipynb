# %%
with open('hello.txt') as hello_file:
    for line in hello_file:
        print(line,end="")
# Out:
# Hello world!
#
# "Programming is an unnatural act."
# - Alan Perlis

# %%
with open('data/seuss.txt') as seuss_file:
    seuss_lines = seuss_file.readlines()

# %%
for line in seuss_lines[0:5]:
    print(line,end="")
# Out:
# The Cat in the Hat
# By Dr. Seuss
#
# The sun did not shine.
# It was too wet to play.

# %%
with open('data/letters.csv') as letters_file:
    letter_table = []
    for line in letters_file:
        line_as_string = line.strip()
        line_as_list = line_as_string.split(",")
        letter_table.append(line_as_list)
        
print(letter_table)
# Out:
# [['a', 'b', 'c', 'd', 'e'], ['g', 'h', 'i', 'j', 'k'], ['m', 'n', 'o', 'p', 'q'], ['v', 'w', 'x', 'y', 'z']]

# %%
import os

# %%
os.getcwd()
# Out:
# 'C:\\Users\\nitem'

# %%
os.chdir('C:\\Users\\nitem\\data')

# %%
os.listdir()
# Out:
# ['.ipynb_checkpoints', 'letters.csv', 'seuss.txt']
